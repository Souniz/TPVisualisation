# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=np.cos(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4908\628464611.py in <module>
# ----> 1 x=np.cos(a)
#
# NameError: name 'np' is not defined

# %%
x1=1.5*np.random.randn(100)

# %%
x2=3*x1+4*np.random.rand(100)

# %%
plt.scatter(x1,x2)

# %%
x3=-2*x2+np.random.randn(100)

# %%
df=pd.DataFrame({'X1':x1,'X2':x2,'X3':x3})
df
# Out:
#           X1        X2         X3
# 0  -1.172093  0.177848  -1.109284
# 1   0.637531  4.882735 -10.526126
# 2  -0.653969 -1.699724   4.450933
# 3   0.252639  3.670222  -8.174507
# 4   0.393698  3.985561  -7.278172
# ..       ...       ...        ...
# 95 -0.053362  2.671777  -4.205667
# 96  2.326944  7.548877 -14.965447
# 97 -1.816205 -2.681120   6.801034
# 98 -0.841174 -1.000325   2.423022
# 99  0.613500  2.135648  -5.502865
#
# [100 rows x 3 columns]

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<AxesSubplot:xlabel='X1', ylabel='X1'>,
#         <AxesSubplot:xlabel='X2', ylabel='X1'>,
#         <AxesSubplot:xlabel='X3', ylabel='X1'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X2'>,
#         <AxesSubplot:xlabel='X2', ylabel='X2'>,
#         <AxesSubplot:xlabel='X3', ylabel='X2'>],
#        [<AxesSubplot:xlabel='X1', ylabel='X3'>,
#         <AxesSubplot:xlabel='X2', ylabel='X3'>,
#         <AxesSubplot:xlabel='X3', ylabel='X3'>]], dtype=object)
